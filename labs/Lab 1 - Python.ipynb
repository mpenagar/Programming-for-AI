# %% [markdown]
# ## Lab 1 - Python

# %% [markdown]
# **1)** There are different ways to get the square root of a number in python. Try to find them and use the Jupyter `%timeit` command to measure the time they need to execute.

# %% [markdown]
# **2)** The execution time of some `list` functions depends on the size of the list, for example, finding the first appearance of a value with `list.index()`. Create a large list of numbers (`list(range(<size>))`) and measure the time needed *on average* to find an element (use the Jupyter `%timeit` command). Suppose that the average search time is the time needed to find an element that is in the middle of the list. Try different sizes $(10^3, 10^4, 10^5, 10^6, \dots)$ and check how the time increases with the length of the list.

# %% [markdown]
# **3)** Write a function `mystr(number)` that takes a natural number and returns its text representation in decimal format. Do not use the built-in `str` function.

# %% [markdown]
# **4)** Write a function `greatest_digits(iterable)` that, given an iterable that contains natural numbers, returns the number with the greatest sum of its digits (in decimal format). For instance, if the input list is `[32, 19, 10012, 587, 2001]`, the function should return `587`.

# %% [markdown]
# **5)** Write a function `greatest_digits(iterable)` that, given an iterable that contains natural numbers, returns a list where integers are sorted according to the sum of their digits (in decimal format). For instance, if the input list is `[32, 19, 10012, 587, 2001]`, the function should return `[2001, 10012, 32, 19, 587]`.

# %% [markdown]
# **6)** Write a generator function `real_range(start, stop, step=1.0)` that returns the sequence of real values $\{start, \;start+step, \;start+2 step, \;\dots, \;a+k \cdot step\}$ where $k$ is the greatest integer such that $start+k \cdot step \,\le\, stop$

# %% [markdown]
# **7)** Write a function `get_min(func, a, b, step=0.001)` that searches the minimum of another function $func(x)$ for $x \in [a,b]$ and the given search step (i.e., the minimum of $func(x)$ for $x \in \{a, \;a+step, \;a+2 step, \;\dots, \;a+k \cdot step\}$

# %% [markdown]
# **8)** Write a function `definite_integral(func, a, b, step=0.001)` that approximates the definite integral of the given function in the interval $[a,b]$ and the given $step$ by:
# $$\int_a^b{func(x) \; dx} \approx \sum_{x \in \{a, \;a+step, \;a+2 step, \;\dots, \;a+k \cdot step\}}{func(x) \cdot step}$$

# %% [markdown]
# **9)** Write a generator function `my_range(start, stop=None, step=1)` that emulates the built-in `range()` function. If a single positional argument is given, it will be used as `stop` and `start=0`.

# %% [markdown]
# **10)** Write a generator function `my_enumerate(iterable, start=0)` that emulates the built-in `enumerate()` function.

# %% [markdown]
# **11)** Write a generator function `naturals(start=1)` that returns the sequence of all natural numbers starting from `start`.

# %% [markdown]
# **12)** Write a function `next_prime(previous_list)` that receives a list of ascending prime numbers `[2, 3, 5, 7, 11, ...]` and returns the next prime number.

# %% [markdown]
# **13)** Write a generator function `primes()` that returns the infinite sequence of prime numbers.

# %% [markdown]
# **14)** Create a function `most_frequent_chars(filename, encoding="utf8", n=10)` that returns a list with the $n$ most frequent characters of a text file, ordered from most to least frequent.

# %% [markdown]
# **15)** Verify (with code) that the functions `random.random()` and `random.randint(a,b)` truly return values following a uniform distribution.

# %% [markdown]
# **16)** Write a class `Vector` that represents an $n$-dimensional vector. The class must implement the following methods:
# * **Initialization**: `__init__(self, *components)` to store a variable number of coordinates.
# * **String Representation**: `__str__(self)` to return the tuple representation of the vector (e.g., "(1, 2, 3)").
# * **Indexing**:
#     * **Get**: `__getitem__` to allow accessing a single dimension value `v[i]`
#     * **Set**: `__setitem__` to allow modifying a single dimension value `v[i]=value`
# * **Addition & Subtraction**: `__add__` and `__sub__` such that
#     * Vector vs. Vector: Element-wise addition and subtraction of two vectors of the same dimension (Raise a ValueError if dimensions do not match).
#     * Vector vs. Scalar: The addition of the vector and a scalar.
# * **Multiplication**: `__mul__` such that
#     * Vector vs. Vector: Element-wise multiplication of two vectors of the same dimension (Raise a ValueError if dimensions do not match).
#     * Vector vs. Scalar: The multiplication of the vector and a scalar.
# * **Dot Product**: `dot(self, other)` the scalar dot product (sum of element-wise products) of two vectors of the same dimension (Raise a ValueError if dimensions do not match).
# * **Magnitude**: `__abs__` to return the Euclidean norm ($\sqrt{\sum x_i^2}$).
