# %%
import numpy as np

# %%
A = np.arange(16).reshape((4, 4))
A

# %%
A + 10

# %%
b = np.array([0,10,100,1000])
print(f'{b = }')
print(f'{A+b = }')

# %%
b2 = b.reshape(1,4)
print(f'{b2 = }')
print(f'{A+b2 = }')

# %%
b3 = b.reshape(4,1)
print(f'{b3 = }')
print(f'{A+b3 = }')
