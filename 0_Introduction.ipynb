# %% [markdown]
# # Programming for AI
#
# ## PART 1: Standard AI programming - Mikel Peñagarikano
#
# 0. **Introduction**
# 1. **Python for Machine Learning**
#    * [Why Python?](1a_Why_Python.ipynb)
#    * [JupyterLab & Jupyter Notebooks](1b_JupyterLab_and_Notebooks.ipynb)
#    * [Python](1c_Python.ipynb) [4s]
#    * [NumPy](1d_NumPy.ipynb) [1s]
#    * [Pandas](1f_Pandas.ipynb) [2s]
#    * [Matplotlib](1e_Matplotlib.ipynb) [1]
# 2. **System and Collaboration Tools**
#    * [Unix/Linux shell](2a_unix_shell.ipynb) [1s]
#    * [Git & GitHub](2b_git_and_github.ipynb) [1s]
#
# ## Part II - Advanced Programming for AI - Tomás Teijeiro
